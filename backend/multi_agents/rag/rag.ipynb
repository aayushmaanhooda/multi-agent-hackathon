# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.tools import tool
from langchain.agents import create_agent
from mem0 import MemoryClient
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone
from langchain_community.document_loaders import TextLoader

from langchain_core.documents import Document

import os

load_dotenv()

name = os.getenv("LANGSMITH_PROJECT")
name
# Out:
# 'hackathon-rag'

# %%
# Load your file
import pandas as pd

df = pd.read_excel("new.xlsx")

def row_to_nl(row):
    """
    Convert one roster row into a meaningful natural-language description
    for RAG embeddings.
    """
    text = (
        f"On {row['Date']} ({row['Day']}), {row['Employee Name']} "
        f"(ID: {row['Employee ID']}) is scheduled for a {row['Hours']}-hour "
        f"{row['Shift Code']} shift from {row['Shift Time']}. "
        f"Employment type: {row['Employment Type']}. "
        f"Status: {row['Status']}. "
        f"Located at Station {row['Station']}, working in Store '{row['Store']}'. "
        f"and the Manager is : {row['Manager']}. "
    )
    
    # Structured metadata for better retrieval
    metadata = {
        "date": row['Date'],
        "employee_name": row['Employee Name'],
        "employee_id": row['Employee ID'],
        "manager": row['Manager'],
        "store": row['Store'],
        "station": row['Station'],
        "shift_code": row['Shift Code']
    }

    return text, metadata

# Apply conversion to every row
nl_chunks = df.apply(row_to_nl, axis=1).tolist()
import json
output_path = "roster_doc.txt"
with open(output_path, "w", encoding="utf-8") as f:
    for text, metadata in nl_chunks:
        combined = (
            f"{text}\n"
            f"Manager: {metadata['manager']} | "
            f"Store: {metadata['store']} | "
            f"Station: {metadata['station']} | "
            f"Employee: {metadata['employee_name']} | "
            f"Date: {metadata['date']}\n"
        )
        f.write(combined + "\n")

nl_chunks[:5]  # show first 5
# Out:
# [("On 2024-12-16 (Monday), John Smith (ID: 1001) is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson. ",
#   {'date': '2024-12-16',
#    'employee_name': 'John Smith',
#    'employee_id': 1001,
#    'manager': 'Mary Wilson',
#    'store': 'Store_1',
#    'station': 'Kitchen',
#    'shift_code': 'S'}),
#  ("On 2024-12-16 (Monday), Mike Brown (ID: 1003) is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson. ",
#   {'date': '2024-12-16',
#    'employee_name': 'Mike Brown',
#    'employee_id': 1003,
#    'manager': 'Mary Wilson',
#    'store': 'Store_1',
#    'station': 'Kitchen',
#    'shift_code': 'S'}),
#  ("On 2024-12-16 (Monday), Alex Wilson (ID: 1005) is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : David Miller. ",
#   {'date': '2024-12-16',
#    'employee_name': 'Alex Wilson',
#    'employee_id': 1005,
#    'manager': 'David Miller',
#    'store': 'Store_1',
#    'station': 'Kitchen',
#    'shift_code': 'S'}),
#  ("On 2024-12-16 (Monday), Sarah Johnson (ID: 1002) is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Robert Johnson. ",
#   {'date': '2024-12-16',
#    'employee_name': 'Sarah Johnson',
#    'employee_id': 1002,
#    'manager': 'Robert Johnson',
#    'store': 'Store_2',
#    'station': 'Kitchen',
#    'shift_code': '1F'}),
#  ("On 2024-12-16 (Monday), Emma Davis (ID: 1004) is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson. ",
#   {'date': '2024-12-16',
#    'employee_name': 'Emma Davis',
#    'employee_id': 1004,
#    'manager': 'Mary Wilson',
#    'store': 'Store_1',
#    'station': 'Kitchen',
#    'shift_code': '1F'})]

# %%
model = init_chat_model("gpt-4.1")
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

pc = Pinecone()
index = pc.Index("hackathon-manager")

vector_store = PineconeVectorStore(embedding=embeddings, index=index)
vector_store

# %%
loader = TextLoader("roster_doc.txt", encoding="utf-8")
docs = loader.load()

print(docs[0].page_content)
# Out:
# On 2024-12-16 (Monday), John Smith (ID: 1001) is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station:
is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: part-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: Ethan Scott | Date: 2024-12-19
#
# On 2024-12-19 (Thursday), Amelia Green (ID: 1024) is scheduled for a 8.5-hour S shift from 06:30-15:00. Employment type: part-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : David Miller.
# Manager: David Miller | Store: Store_1 | Station: Kitchen | Employee: Amelia Green | Date: 2024-12-19
#
# On 2024-12-19 (Thursday), Mason Adams (ID: 1025) is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: part-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Kitchen | Employee: Mason Adams | Date: 2024-12-19
#
# On 2024-12-19 (Thursday), Harper Nelson (ID: 1026) is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Kitchen | Employee: Harper Nelson | Date: 2024-12-19
#
# On 2024-12-19 (Thursday), Logan Carter (ID: 1027) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Linda Anderson.
# Manager: Linda Anderson | Store: Store_2 | Station: Kitchen | Employee: Logan Carter | Date: 2024-12-19
#
# On 2024-12-19 (Thursday), Evelyn Mitchell (ID: 1028) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Robert Johnson.
# Manager: Robert Johnson | Store: Store_2 | Station: Kitchen | Employee: Evelyn Mitchell | Date: 2024-12-19
#
# On 2024-12-20 (Friday), John Smith (ID: 1001) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Kitchen | Employee: John Smith | Date: 2024-12-20
#
# On 2024-12-20 (Friday), Sarah Johnson (ID: 1002) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Jennifer Davis.
# Manager: Jennifer Davis | Store: Store_2 | Station: Kitchen | Employee: Sarah Johnson | Date: 2024-12-20
#
# On 2024-12-20 (Friday), Mike Brown (ID: 1003) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Kitchen | Employee: Mike Brown | Date: 2024-12-20
#
# On 2024-12-20 (Friday), Emma Davis (ID: 1004) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: Emma Davis | Date: 2024-12-20
#
# On 2024-12-20 (Friday), Jackson Perez (ID: 1029) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Counter | Employee: Jackson Perez | Date: 2024-12-20
#
# On 2024-12-20 (Friday), Abigail Roberts (ID: 1030) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Linda Anderson.
# Manager: Linda Anderson | Store: Store_2 | Station: Counter | Employee: Abigail Roberts | Date: 2024-12-20
#
# On 2024-12-21 (Saturday), Alex Wilson (ID: 1005) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: Alex Wilson | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Lisa Anderson (ID: 1006) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Counter | Employee: Lisa Anderson | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Tom Martinez (ID: 1007) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Counter | Employee: Tom Martinez | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Rachel Green (ID: 1008) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: part-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Rachel Green | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Liam Phillips (ID: 1031) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Liam Phillips | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Charlotte Campbell (ID: 1032) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Jennifer Davis.
# Manager: Jennifer Davis | Store: Store_2 | Station: Counter | Employee: Charlotte Campbell | Date: 2024-12-21
#
# On 2024-12-21 (Saturday), Benjamin Parker (ID: 1033) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: part-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Benjamin Parker | Date: 2024-12-21
#
# On 2024-12-22 (Sunday), Chris Taylor (ID: 1009) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: part-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Chris Taylor | Date: 2024-12-22
#
# On 2024-12-22 (Sunday), Anna White (ID: 1010) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: part-time. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_2'. and the Manager is : Linda Anderson.
# Manager: Linda Anderson | Store: Store_2 | Station: Multi-Station McCafe | Employee: Anna White | Date: 2024-12-22
#
# On 2024-12-22 (Sunday), David Black (ID: 1011) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Multi-Station McCafe | Employee: David Black | Date: 2024-12-22
#
# On 2024-12-22 (Sunday), Sophie Lee (ID: 1012) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Dessert Station, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station:
is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Linda Anderson.
# Manager: Linda Anderson | Store: Store_2 | Station: Counter | Employee: Lucas Edwards | Date: 2024-12-26
#
# On 2024-12-26 (Thursday), John Smith (ID: 1001) is scheduled for a 9.0-hour 1F shift from 06:30-15:30. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: John Smith | Date: 2024-12-26
#
# On 2024-12-26 (Thursday), Sarah Johnson (ID: 1002) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Linda Anderson.
# Manager: Linda Anderson | Store: Store_2 | Station: Kitchen | Employee: Sarah Johnson | Date: 2024-12-26
#
# On 2024-12-26 (Thursday), Mike Brown (ID: 1003) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: Mike Brown | Date: 2024-12-26
#
# On 2024-12-27 (Friday), Emma Davis (ID: 1004) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Richard Moore.
# Manager: Richard Moore | Store: Store_1 | Station: Kitchen | Employee: Emma Davis | Date: 2024-12-27
#
# On 2024-12-27 (Friday), Alex Wilson (ID: 1005) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : David Miller.
# Manager: David Miller | Store: Store_1 | Station: Kitchen | Employee: Alex Wilson | Date: 2024-12-27
#
# On 2024-12-27 (Friday), Lisa Anderson (ID: 1006) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : David Miller.
# Manager: David Miller | Store: Store_1 | Station: Counter | Employee: Lisa Anderson | Date: 2024-12-27
#
# On 2024-12-27 (Friday), Tom Martinez (ID: 1007) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: full-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : David Miller.
# Manager: David Miller | Store: Store_1 | Station: Counter | Employee: Tom Martinez | Date: 2024-12-27
#
# On 2024-12-27 (Friday), Rachel Green (ID: 1008) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: part-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Jennifer Davis.
# Manager: Jennifer Davis | Store: Store_2 | Station: Counter | Employee: Rachel Green | Date: 2024-12-27
#
# On 2024-12-27 (Friday), Chris Taylor (ID: 1009) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: part-time. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Chris Taylor | Date: 2024-12-27
#
# On 2024-12-28 (Saturday), Anna White (ID: 1010) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: part-time. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Multi-Station McCafe | Employee: Anna White | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), David Black (ID: 1011) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Multi-Station McCafe | Employee: David Black | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), Sophie Lee (ID: 1012) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Dessert Station, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Dessert Station | Employee: Sophie Lee | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), Mark Harris (ID: 1013) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Kitchen | Employee: Mark Harris | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), Emma Clark (ID: 1014) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_2'. and the Manager is : Robert Johnson.
# Manager: Robert Johnson | Store: Store_2 | Station: Kitchen | Employee: Emma Clark | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), James Lewis (ID: 1015) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Kitchen, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Kitchen | Employee: James Lewis | Date: 2024-12-28
#
# On 2024-12-28 (Saturday), Olivia Walker (ID: 1016) is scheduled for a 9.0-hour SC shift from 11:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Jennifer Davis.
# Manager: Jennifer Davis | Store: Store_2 | Station: Counter | Employee: Olivia Walker | Date: 2024-12-28
#
# On 2024-12-29 (Sunday), Benjamin Hall (ID: 1017) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Counter | Employee: Benjamin Hall | Date: 2024-12-29
#
# On 2024-12-29 (Sunday), Isabella Young (ID: 1018) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Counter | Employee: Isabella Young | Date: 2024-12-29
#
# On 2024-12-29 (Sunday), Lucas King (ID: 1019) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Counter, working in Store 'Store_1'. and the Manager is : David Miller.
# Manager: David Miller | Store: Store_1 | Station: Counter | Employee: Lucas King | Date: 2024-12-29
#
# On 2024-12-29 (Sunday), Mia Wright (ID: 1020) is scheduled for a 12.0-hour 3F shift from 08:00-20:00. Employment type: casual. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_1'. and the Manager is : Mary Wilson.
# Manager: Mary Wilson | Store: Store_1 | Station: Multi-Station McCafe | Employee: Mia Wright | Date: 2024-12-29
#
# On 2024-12-29 (Sunday), Noah Lopez (ID: 1021) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: full-time. Status: Scheduled. Located at Station Multi-Station McCafe, working in Store 'Store_2'. and the Manager is : Michael Brown.
# Manager: Michael Brown | Store: Store_2 | Station: Multi-Station McCafe | Employee: Noah Lopez | Date: 2024-12-29
#
# On 2024-12-29 (Sunday), Ava Hill (ID: 1022) is scheduled for a 9.0-hour 2F shift from 14:00-23:00. Employment type: full-time. Status: Scheduled. Located at Station Dessert Station, working in Store 'Store_1'. and the Manager is : Patricia Williams.
# Manager: Patricia Williams | Store: Store_1 | Station: Dessert Station | Employee: Ava Hill | Date: 2024-12-29

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_splits = text_splitter.split_documents(docs)
print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 46 sub-documents.

# %%
document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ['889f0cda-9763-4475-93d5-a1b28bde0d04', 'd719e7a2-0ab4-4c32-83a1-1b9cdc9f03ea', 'ae1e247c-9b19-43e7-9079-918347efc1eb']

# %%
@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    # Increase k for queries about managers, stores, or general information
    # to get more comprehensive results
    # Increase k for queries about employees, managers, stores, or general information
    # to get more comprehensive results
    k = 15 if any(keyword in query.lower() for keyword in ['manager', 'store', 'who', 'list', 'all', 'employee', 's manager', 'manager?']) else 10
    retrieved_docs = vector_store.similarity_search(query, k=k)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %%
tools = [retrieve_context]
# If desired, specify custom instructions
prompt = (
    """
    You are an intelligent Roster Management Assistant for a 14-day employee schedule system. 
Your job is to accurately answer admin queries using the roster data retrieved from the RAG tool.
Shift Code Metadata:

1F: Front Counter – Morning  
2F: Front Counter – Afternoon  
3F: Front Counter – Evening  
1B: Back Area / Grill – Morning  
2B: Back Area / Grill – Afternoon  
3B: Back Area / Grill – Evening

==========================
 HOW YOU USE THE RAG TOOL
==========================
• You ONLY answer using the context retrieved through the roster-retrieval tool.  
• The retrieval tool returns natural-language descriptions of roster entries for 14 consecutive days.
• If the retrieved context does NOT contain the employee or role the admin is asking for, reply exactly:
  "This role is not filled in the system as of now."

==========================
 HOW YOU UNDERSTAND DATES
==========================
• The roster contains **exact dates** for 14 days (lowest date → highest date).  
• “First Monday”, “Second Friday”, “next Tuesday”, etc. refer to the occurrences **within the 14-day window**, not the calendar month.  
• To interpret “first Monday”, identify the earliest date labeled Monday.  
• To interpret “second Monday”, identify the second occurrence of Monday.  
• When the admin asks about a “week”, treat each consecutive set of 7 days starting from the earliest date as Week 1 and Week 2.

==========================
 HOW TO HANDLE EMPLOYEE QUERIES
==========================
• If an employee name exists in the retrieved data, summarize all relevant shifts:
    - Date
    - Day
    - Shift code / shift time
    - Hours
    - Status
• If the admin asks about:
    - “Who is working on <date/day>?”
    - “Is <employee> free on <date>?”
    - “Who covers the morning shift on the second Wednesday?”
  …use the retrieved roster entries to answer directly and concisely.

==========================
 ANSWERING STYLE
==========================
• Be accurate, structured, and concise and answer in natural language.
• If multiple relevant entries exist, summarize them clearly.
• NEVER make up data. NEVER guess.
• ONLY rely on the retrieved tool output.

==========================
WHEN YOU MUST SAY
"This role is not filled in the system as of now."
==========================
• Name not found in context
• Role not found in context
• No matching shift in context
• No retrieved data at all

==========================
GOAL
==========================
Provide correct, reliable answers about employee schedules, shift details, availability, and roster insights over the 14-day period using ONLY the provided RAG context.

    """
)
agent = create_agent(model, tools, system_prompt=prompt)

# %%
query = (
    "who is working on monday afternooshift in kitchen ??"
)

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# who is working on monday afternooshift in kitchen ??
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_ieieciId3jj4GEAHdXP9jyfa)
#  Call ID: call_ieieciId3jj4GEAHdXP9jyfa
#   Args:
#     query: Monday afternoon shift in kitchen
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'Date': '2024-12-16', 'Day': 'Monday', 'Employee ID': 1003.0, 'Employee Name': 'Mike Brown', 'Employment Type': 'full-time', 'Hours': 8.5, 'Manager': 'Mary Wilson', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 1.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-16 | Day: Monday | Store: Store_1 | Employee ID: 1003 | Employee Name: Mike Brown | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: full-time | Manager: Mary Wilson | Status: Scheduled
#
# Source: {'Date': '2024-12-25', 'Day': 'Wednesday', 'Employee ID': 1028.0, 'Employee Name': 'Evelyn Mitchell', 'Employment Type': 'casual', 'Hours': 8.5, 'Manager': 'Michael Brown', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_2', 'row_id': 62.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-25 | Day: Wednesday | Store: Store_2 | Employee ID: 1028 | Employee Name: Evelyn Mitchell | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: casual | Manager: Michael Brown | Status: Scheduled
#
# Source: {'Date': '2024-12-24', 'Day': 'Tuesday', 'Employee ID': 1025.0, 'Employee Name': 'Mason Adams', 'Employment Type': 'part-time', 'Hours': 9.0, 'Manager': 'Mary Wilson', 'Shift Code': '2F', 'Shift Time': '14:00-23:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 59.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-24 | Day: Tuesday | Store: Store_1 | Employee ID: 1025 | Employee Name: Mason Adams | Station: Kitchen | Shift Code: 2F | Shift Time: 14:00-23:00 | Hours: 9.0 | Employment Type: part-time | Manager: Mary Wilson | Status: Scheduled
#
# Source: {'Date': '2024-12-23', 'Day': 'Monday', 'Employee ID': 1015.0, 'Employee Name': 'James Lewis', 'Employment Type': 'casual', 'Hours': 8.5, 'Manager': 'Patricia Williams', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 49.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-23 | Day: Monday | Store: Store_1 | Employee ID: 1015 | Employee Name: James Lewis | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: casual | Manager: Patricia Williams | Status: Scheduled
#
# Source: {'Date': '2024-12-19', 'Day': 'Thursday', 'Employee ID': 1025.0, 'Employee Name': 'Mason Adams', 'Employment Type': 'part-time', 'Hours': 9.0, 'Manager': 'Mary Wilson', 'Shift Code': '1F', 'Shift Time': '06:30-15:30', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 24.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-19 | Day: Thursday | Store: Store_1 | Employee ID: 1025 | Employee Name: Mason Adams | Station: Kitchen | Shift Code: 1F | Shift Time: 06:30-15:30 | Hours: 9.0 | Employment Type: part-time | Manager: Mary Wilson | Status: Scheduled
#
# Source: {'Date': '2024-12-16', 'Day': 'Monday', 'Employee ID': 1001.0, 'Employee Name': 'John Smith', 'Employment Type': 'full-time', 'Hours': 8.5, 'Manager': 'Mary Wilson', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 0.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-16 | Day: Monday | Store: Store_1 | Employee ID: 1001 | Employee Name: John Smith | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: full-time | Manager: Mary Wilson | Status: Scheduled
#
# Source: {'Date': '2024-12-23', 'Day': 'Monday', 'Employee ID': 1013.0, 'Employee Name': 'Mark Harris', 'Employment Type': 'casual', 'Hours': 8.5, 'Manager': 'Jennifer Davis', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_2', 'row_id': 47.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-23 | Day: Monday | Store: Store_2 | Employee ID: 1013 | Employee Name: Mark Harris | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: casual | Manager: Jennifer Davis | Status: Scheduled
#
# Source: {'Date': '2024-12-24', 'Day': 'Tuesday', 'Employee ID': 1024.0, 'Employee Name': 'Amelia Green', 'Employment Type': 'part-time', 'Hours': 9.0, 'Manager': 'Richard Moore', 'Shift Code': '1F', 'Shift Time': '06:30-15:30', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 58.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-24 | Day: Tuesday | Store: Store_1 | Employee ID: 1024 | Employee Name: Amelia Green | Station: Kitchen | Shift Code: 1F | Shift Time: 06:30-15:30 | Hours: 9.0 | Employment Type: part-time | Manager: Richard Moore | Status: Scheduled
#
# Source: {'Date': '2024-12-19', 'Day': 'Thursday', 'Employee ID': 1028.0, 'Employee Name': 'Evelyn Mitchell', 'Employment Type': 'casual', 'Hours': 9.0, 'Manager': 'Robert Johnson', 'Shift Code': '2F', 'Shift Time': '14:00-23:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_2', 'row_id': 27.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-19 | Day: Thursday | Store: Store_2 | Employee ID: 1028 | Employee Name: Evelyn Mitchell | Station: Kitchen | Shift Code: 2F | Shift Time: 14:00-23:00 | Hours: 9.0 | Employment Type: casual | Manager: Robert Johnson | Status: Scheduled
#
# Source: {'Date': '2024-12-19', 'Day': 'Thursday', 'Employee ID': 1024.0, 'Employee Name': 'Amelia Green', 'Employment Type': 'part-time', 'Hours': 8.5, 'Manager': 'David Miller', 'Shift Code': 'S', 'Shift Time': '06:30-15:00', 'Station': 'Kitchen', 'Status': 'Scheduled', 'Store': 'Store_1', 'row_id': 23.0, 'source': 'excel_data', 'start_index': 0.0}
# Content: Date: 2024-12-19 | Day: Thursday | Store: Store_1 | Employee ID: 1024 | Employee Name: Amelia Green | Station: Kitchen | Shift Code: S | Shift Time: 06:30-15:00 | Hours: 8.5 | Employment Type: part-time | Manager: David Miller | Status: Scheduled
# ================================== Ai Message ==================================
#
# On both Mondays within the roster period, the following employees are working kitchen shifts in the afternoon (based on available shift times):
#
# - 2024-12-16 (Monday):
#   - John Smith | Shift time: 06:30-15:00 | Hours: 8.5 | Status: Scheduled
#   - Mike Brown | Shift time: 06:30-15:00 | Hours: 8.5 | Status: Scheduled
#
# - 2024-12-23 (Monday):
#   - James Lewis | Shift time: 06:30-15:00 | Hours: 8.5 | Status: Scheduled
#   - Mark Harris | Shift time: 06:30-15:00 | Hours: 8.5 | Status: Scheduled
#
# These shifts cover both late morning and afternoon hours in the kitchen.
